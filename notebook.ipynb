# %%
# check one h5 file
import h5py
import numpy as np

file_path = r"D:\Datasets\BraTS2020_training_data\content\data\volume_2_slice_21.h5"

with h5py.File(file_path, 'r') as hf:
    print("Keys in H5 file:", list(hf.keys()))
    image_data = hf['image'][:]
    mask_data = hf['mask'][:]

    print("Image shape:", image_data.shape)
    print("Mask shape:", mask_data.shape)
# Out:
# Keys in H5 file: ['image', 'mask']
# Image shape: (240, 240, 4)
# Mask shape: (240, 240, 3)

# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached jiter-0.13.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.1 MB 5.2 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 10.3 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...
